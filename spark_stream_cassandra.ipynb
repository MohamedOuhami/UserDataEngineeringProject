# %% [markdown]
# ## Spark jobs to add Data from Kafka to Cassandra

# %%
import logging
from uuid import uuid4
from cassandra.auth import PlainTextAuthProvider
from cassandra.cluster import Cluster
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col
from pyspark.sql.types import StructField, StructType, StringType

# %%
#  Configure logging
logging.basicConfig(level=logging.INFO)

def create_keyspace(session):
    try:
        session.execute(""" 
        CREATE KEYSPACE IF NOT EXISTS spark_streams 
        WITH replication = {'class':'SimpleStrategy', 'replication_factor':'1'} 
        """)
        logging.info("Keyspace created successfully")
    except Exception as e:
        logging.error(f"Failed to create keyspace due to: {e}")

# %%
def create_table(session):
    try:
        session.execute(""" 
        CREATE TABLE IF NOT EXISTS spark_streams.created_users ( 
            id UUID PRIMARY KEY, 
            first_name TEXT, 
            last_name TEXT, 
            address TEXT, 
            email TEXT, 
            username TEXT, 
            dob TEXT, 
            phone TEXT, 
            profile_pic TEXT, 
            nationality TEXT 
        ) 
        """)
        logging.info("Table created successfully")
    except Exception as e:
        logging.error(f"Failed to create table due to: {e}")

# %%
from uuid import uuid4  # Ensure this is imported

def insert_data(session, **kwargs):
    try:
        session.execute(""" 
        INSERT INTO spark_streams.created_users(id, first_name, last_name, address, email, username, dob, phone, profile_pic, nationality) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s) 
        """, ( 
            uuid4(),
            kwargs.get("first_name"), 
            kwargs.get("last_name"), 
            kwargs.get("address"), 
            kwargs.get("email"), 
            kwargs.get("username"), 
            kwargs.get("dob"), 
            kwargs.get("phone"), 
            kwargs.get("profile_pic"), 
            kwargs.get("nationality") 
        )) 
        logging.info("Data inserted successfully")
    except Exception as e:
        logging.error(f"Could not add the data due to {e}")

# %%
def create_spark_connection():
    try:
        s_conn = SparkSession.builder \
            .appName('SparkDataBatch') \
            .config('spark.jars.packages', "com.datastax.spark:spark-cassandra-connector_2.12:3.5.1," 
                                           "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.1") \
            .config('spark.cassandra.connection.host', 'localhost') \
            .getOrCreate()
        
        s_conn.sparkContext.setLogLevel("ERROR")
        logging.info("Spark Connection created successfully")
        return s_conn
    except Exception as e:
        logging.error(f"An error occurred while creating Spark connection: {e}")
        return None

# %%
def cassandra_connection():
    try:
        cluster = Cluster(['localhost'])  # Using localhost for Cassandra
        session = cluster.connect()
        logging.info("Cassandra connection established successfully")
        return session
    except Exception as e:
        logging.error(f"Couldn't establish Cassandra connection due to {e}")
        return None

# %%
def connect_to_kafka(spark_conn):
    try:
        spark_df = spark_conn.read \
        .format('kafka') \
        .option('kafka.bootstrap.servers', 'localhost:9092') \
        .option('subscribe', 'users_created') \
        .option('startingOffsets', 'earliest') \
        .load()
        logging.info("Kafka DataFrame created successfully")
        
        return spark_df
    except Exception as e:
        logging.error(f"Error creating the DataFrame from Kafka: {e}")
        return None

# %%
def create_selection_df_from_kafka(spark_df):
    schema = StructType([ 
        StructField('id', StringType(), False), 
        StructField('first_name', StringType(), False), 
        StructField('last_name', StringType(), False), 
        StructField('address', StringType(), False), 
        StructField('email', StringType(), False), 
        StructField('username', StringType(), False), 
        StructField('dob', StringType(), False), 
        StructField('phone', StringType(), False), 
        StructField('profile_pic', StringType(), False), 
        StructField('nationality', StringType(), False), 
    ])   
    
    # Select value from Kafka and print the raw messages
    raw_df = spark_df.selectExpr('CAST(value AS STRING)') 

    # Write the raw messages to console for debugging
    raw_df.show(truncate=False)
    
    # Attempt to parse the JSON schema
    try:
        sel = raw_df.select(from_json(col('value'), schema).alias('data')).select("data.*")
        logging.info("Selection DataFrame created successfully")
        logging.info("Schema matches expected structure.")
    except Exception as e:
        logging.error(f"Schema mismatch or other error occurred: {e}")
        sel = None
    
    return sel

# %%
def write_to_cassandra(select_df, session):
    # Collect the DataFrame rows and insert into Cassandra
    try:
        for row in select_df.collect():
            insert_data(session, **row.asDict())
        logging.info("Data written to Cassandra successfully")
    except Exception as e:
        logging.error(f"Failed to write data to Cassandra: {e}")

# %%
spark_conn = create_spark_connection()
session = cassandra_connection()

if spark_conn and session:
    create_keyspace(session)
    create_table(session)
    
    df = connect_to_kafka(spark_conn)
    if df:
        select_df = create_selection_df_from_kafka(spark_df=df)

        # Validate incoming data schema
        schema = StructType([ 
            StructField('id', StringType(), False), 
            StructField('first_name', StringType(), False), 
            StructField('last_name', StringType(), False), 
            StructField('address', StringType(), False), 
            StructField('email', StringType(), False), 
            StructField('username', StringType(), False), 
            StructField('dob', StringType(), False), 
            StructField('phone', StringType(), False), 
            StructField('profile_pic', StringType(), False), 
            StructField('nationality', StringType(), False), 
        ])
        
        # Write to Cassandra
        write_to_cassandra(select_df, session)

# Close the session
if session:
    session.shutdown()
# Out:
# INFO:root:Spark Connection created successfully
# WARNING:cassandra.cluster:Cluster.__init__ called with contact_points specified, but no load_balancing_policy. In the next major version, this will raise an error; please specify a load-balancing policy. (contact_points = ['localhost'], lbp = None)
# WARNING:cassandra.cluster:Downgrading core protocol version from 66 to 65 for ::1:9042. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# WARNING:cassandra.cluster:Downgrading core protocol version from 65 to 5 for ::1:9042. To avoid this, it is best practice to explicitly set Cluster(protocol_version) to the version supported by your cluster. http://datastax.github.io/python-driver/api/cassandra/cluster.html#cassandra.cluster.Cluster.protocol_version
# INFO:cassandra.policies:Using datacenter 'datacenter1' for DCAwareRoundRobinPolicy (via host '::1:9042'); if incorrect, please specify a local_dc to the constructor, or limit contact points to local cluster nodes
# INFO:cassandra.cluster:Cassandra host 127.0.0.1:9042 removed
# INFO:root:Cassandra connection established successfully
# INFO:root:Keyspace created successfully
# INFO:root:Table created successfully
# INFO:root:Kafka DataFrame created successfully
# INFO:root:Selection DataFrame created successfully
# INFO:root:Schema matches expected structure.
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |value                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{"first_name": "Ramon", "last_name": "Holland", "address": "Hickory Creek Dr ,Odessa ,Louisiana ,United States", "email": "ramon.holland@example.com", "username": "biggorilla167", "dob": "1976-08-31T01:41:32.544Z", "phone": "(856) 589-0953", "profile_pic": "https://randomuser.me/api/portraits/med/men/80.jpg", "nationality": "US"}                                                                                                                                                                       |
# |{"first_name": "Ilonka", "last_name": "Hartwich", "address": "Waldstra\u00dfe ,Rockenhausen ,Sachsen-Anhalt ,Germany", "email": "ilonka.hartwich@example.com", "username": "angrybear193", "dob": "1946-06-04T14:29:43.360Z", "phone": "0772-9212979", "profile_pic": "https://randomuser.me/api/portraits/med/women/21.jpg", "nationality": "DE"}                                                                                                                                                                |
# |{"first_name": "Menek\u015fe", "last_name": "Polling", "address": "Dokter G van Empelstraat ,Badhoevedorp ,Gelderland ,Netherlands", "email": "menekse.polling@example.com", "username": "brownbear531", "dob": "1950-09-15T05:39:42.022Z", "phone": "(0101) 553347", "profile_pic": "https://randomuser.me/api/portraits/med/women/43.jpg", "nationality": "NL"}                                                                                                                                                 |
# |{"first_name": "Aryan", "last_name": "Rai", "address": "Gandhi Maidan Marg ,Darbhanga ,Jharkhand ,India", "email": "aryan.rai@example.com", "username": "angrybear260", "dob": "1978-07-26T19:13:05.571Z", "phone": "9925553866", "profile_pic": "https://randomuser.me/api/portraits/med/men/95.jpg", "nationality": "IN"}                                                                                                                                                                                       |
# |{"first_name": "Amanda", "last_name": "Wuollet", "address": "Mechelininkatu ,Hausj\u00e4rvi ,Northern Ostrobothnia ,Finland", "email": "amanda.wuollet@example.com", "username": "beautifulcat633", "dob": "1962-03-16T00:27:46.200Z", "phone": "08-716-242", "profile_pic": "https://randomuser.me/api/portraits/med/women/31.jpg", "nationality": "FI"}                                                                                                                                                         |
# |{"first_name": "Frederikke", "last_name": "Johansen", "address": "N\u00f8rrevej ,Sams\u00f8 ,Hovedstaden ,Denmark", "email": "frederikke.johansen@example.com", "username": "redkoala393", "dob": "1983-01-26T08:39:34.703Z", "phone": "67015076", "profile_pic": "https://randomuser.me/api/portraits/med/men/79.jpg", "nationality": "DK"}                                                                                                                                                                      |
# |{"first_name": "\u0645\u0631\u06cc\u0645", "last_name": "\u06a9\u0631\u06cc\u0645\u06cc", "address": "\u0645\u06cc\u0631\u062f\u0627\u0645\u0627\u062f ,\u0622\u0645\u0644 ,\u06a9\u0647\u06af\u06cc\u0644\u0648\u06cc\u0647 \u0648 \u0628\u0648\u06cc\u0631\u0627\u062d\u0645\u062f ,Iran", "email": "mrym.khrymy@example.com", "username": "happycat573", "dob": "1979-05-05T07:03:53.591Z", "phone": "025-69866658", "profile_pic": "https://randomuser.me/api/portraits/med/women/8.jpg", "nationality": "IR"}|
# |{"first_name": "Ru\u017ea", "last_name": "Karad\u017ei\u0107", "address": "Jove Mitrovi\u0107a ,\u017dabalj ,Toplica ,Serbia", "email": "ruza.karadzic@example.com", "username": "bluezebra300", "dob": "1992-12-25T20:41:19.404Z", "phone": "023-6776-074", "profile_pic": "https://randomuser.me/api/portraits/med/women/23.jpg", "nationality": "RS"}                                                                                                                                                          |
# |{"first_name": "Eleonora", "last_name": "Martinez", "address": "Cours Charlemagne ,Froideville ,Thurgau ,Switzerland", "email": "eleonora.martinez@example.com", "username": "heavybird877", "dob": "1965-05-20T00:40:34.883Z", "phone": "079 323 79 32", "profile_pic": "https://randomuser.me/api/portraits/med/women/11.jpg", "nationality": "CH"}                                                                                                                                                             |
# |{"first_name": "Nicole", "last_name": "Silva", "address": "Highfield Road ,Waterford ,Mayo ,Ireland", "email": "nicole.silva@example.com", "username": "blackpanda968", "dob": "1988-11-22T17:37:21.493Z", "phone": "021-862-7739", "profile_pic": "https://randomuser.me/api/portraits/med/women/22.jpg", "nationality": "IE"}                                                                                                                                                                                   |
# |{"first_name": "Lisa", "last_name": "Moore", "address": "Springfield Road ,Salisbury ,Devon ,United Kingdom", "email": "lisa.moore@example.com", "username": "bluecat218", "dob": "1951-11-22T20:17:21.335Z", "phone": "016977 93053", "profile_pic": "https://randomuser.me/api/portraits/med/women/86.jpg", "nationality": "GB"}                                                                                                                                                                                |
# |{"first_name": "Dylan", "last_name": "Walker", "address": "Anglesea Street ,Dunedin ,Bay of Plenty ,New Zealand", "email": "dylan.walker@example.com", "username": "smallfish890", "dob": "1950-08-08T03:18:10.913Z", "phone": "(024)-124-0185", "profile_pic": "https://randomuser.me/api/portraits/med/men/57.jpg", "nationality": "NZ"}                                                                                                                                                                        |
# |{"first_name": "Antoine", "last_name": "Menard", "address": "Rue Abel-Ferry ,Aix-En-Provence ,Martinique ,France", "email": "antoine.menard@example.com", "username": "yellowkoala617", "dob": "1981-03-13T05:43:10.358Z", "phone": "04-08-46-24-34", "profile_pic": "https://randomuser.me/api/portraits/med/men/80.jpg", "nationality": "FR"}                                                                                                                                                                   |
# |{"first_name": "Amy", "last_name": "Addy", "address": "Maple Ave ,Charlottetown ,Nunavut ,Canada", "email": "amy.addy@example.com", "username": "whiteleopard768", "dob": "1986-08-31T06:02:14.537Z", "phone": "W83 B11-1946", "profile_pic": "https://randomuser.me/api/portraits/med/women/90.jpg", "nationality": "CA"}                                                                                                                                                                                        |
# |{"first_name": "Lumi", "last_name": "Lampo", "address": "Pirkankatu ,Ilmajoki ,Lapland ,Finland", "email": "lumi.lampo@example.com", "username": "whitemeercat120", "dob": "1962-01-19T01:52:36.859Z", "phone": "06-966-955", "profile_pic": "https://randomuser.me/api/portraits/med/women/58.jpg", "nationality": "FI"}                                                                                                                                                                                         |
# |{"first_name": "Ulichan", "last_name": "Yarockiy", "address": "Ploshcha Grendzhi-Donskogo ,Novoyavorivsk ,Hersonska ,Ukraine", "email": "ulichan.yarockiy@example.com", "username": "purplesnake545", "dob": "1983-11-18T08:32:02.514Z", "phone": "(067) T94-2617", "profile_pic": "https://randomuser.me/api/portraits/med/men/67.jpg", "nationality": "UA"}                                                                                                                                                     |
# |{"first_name": "Aria", "last_name": "Walker", "address": "Highbrook Drive ,Hamilton ,Waikato ,New Zealand", "email": "aria.walker@example.com", "username": "greenfish887", "dob": "1998-02-03T13:37:04.056Z", "phone": "(721)-126-2522", "profile_pic": "https://randomuser.me/api/portraits/med/women/39.jpg", "nationality": "NZ"}                                                                                                                                                                             |
# |{"first_name": "Olivier", "last_name": "Morin", "address": "Simcoe St ,Russell ,Manitoba ,Canada", "email": "olivier.morin@example.com", "username": "crazygoose877", "dob": "1948-04-07T12:03:45.142Z", "phone": "Y17 D42-4166", "profile_pic": "https://randomuser.me/api/portraits/med/men/15.jpg", "nationality": "CA"}                                                                                                                                                                                       |
# |{"first_name": "Atharv", "last_name": "Chiplunkar", "address": "MG Rd Bangalore ,Dhule ,Karnataka ,India", "email": "atharv.chiplunkar@example.com", "username": "beautifullion422", "dob": "1991-05-21T19:08:06.355Z", "phone": "9900629923", "profile_pic": "https://randomuser.me/api/portraits/med/men/97.jpg", "nationality": "IN"}                                                                                                                                                                          |
# |{"first_name": "Karen", "last_name": "Clement", "address": "Rue Bony ,\u00c9vilard ,Schaffhausen ,Switzerland", "email": "karen.clement@example.com", "username": "ticklishmouse669", "dob": "1992-12-11T21:22:43.096Z", "phone": "077 042 78 63", "profile_pic": "https://randomuser.me/api/portraits/med/women/51.jpg", "nationality": "CH"}                                                                                                                                                                    |
# +------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# ...
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data inserted successfully
# INFO:root:Data written to Cassandra successfully
